# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.metrics import accuracy_score

# %%
X_train = np.array([[1,1],[2,2],[3,3],[4,4]])
y_train=np.array([0,0,1,1])

# %%
X_test=np.array([[0,0]])

# %%
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
prediction=knn.predict(X_test)

# %%
print(prediction)
# Out:
# [0]

# %%
import matplotlib.pyplot as plt

# %%
plot=plt.scatter(X_train[:,0],X_train[:,1])
plt.xlabel('Study')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
y_test = np.array([1])

# %%
accuracy = accuracy_score(y_test, prediction)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.0

# %%
import pandas as pd

# %%
df=pd.read_csv("dataset.csv")

# %%
X_train=df[["Smoke","Lungs Capacity"]]

# %%
y_train=df["Cancer"]

# %%
plt.scatter(df["Smoke"],df["Lungs Capacity"])
plt.xlabel("Smoke")
plt.ylabel("Lungs Capacity")
# Out:
# Text(0, 0.5, 'Lungs Capacity')

# %%
knn1=KNeighborsClassifier(n_neighbors=3)

# %%
knn1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_test=np.array([[7,5]])

# %%
prediction1=knn1.predict(y_test)
# Out:
# /home/noone/Documents/jupyternotebook/env/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print(prediction1)
# Out:
# ['Yes']
